# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
dff='/content/drive/My Drive/dhoni/final3.csv'
d1=pd.read_csv(dff)

# %%
d1
# Out:
#       Unnamed: 0        Date         Open          Low         High  \
# 0              0  2010-01-05  1132.660034  1129.660034  1136.630005
# 1              1  2010-01-06  1135.709961  1133.949951  1139.189941
# 2              2  2010-01-07  1136.270020  1131.319946  1142.459961
# 3              3  2010-01-08  1140.520020  1136.219971  1145.390015
# 4              4  2010-01-11  1145.959961  1142.020020  1149.739990
# ...          ...         ...          ...          ...          ...
# 3671        1064  2022-09-23   283.089996   272.820007   284.500000
# 3672        1065  2022-09-26   271.829987   270.309998   284.089996
# 3673        1066  2022-09-27   283.839996   277.510010   288.670013
# 3674        1067  2022-09-28   283.079987   277.570007   289.000000
# 3675        1068  2022-09-29   282.760010   265.779999   283.649994
#
#             Close    Adj Close      Volume  sentiment_score
# 0     1136.520020  1136.520020  2491020000         0.489590
# 1     1137.140015  1137.140015  4972660000         0.726645
# 2     1141.689941  1141.689941  5270680000         0.546994
# 3     1144.979980  1144.979980  4389590000         0.576376
# 4     1146.979980  1146.979980  4255780000         0.856173
# ...           ...          ...         ...              ...
# 3671   275.329987   275.329987    63748400         0.149131
# 3672   276.010010   276.010010    58076900         0.135966
# 3673   282.940002   282.940002    61925200         0.157954
# 3674   287.809998   287.809998    54664800         0.113234
# 3675   268.209991   268.209991    77620600         0.077263
#
# [3676 rows x 9 columns]

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
lin=LinearRegression()
x=d1[['Open','Low','High','sentiment_score','Volume']]
y=d1['Close']


X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lin.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.ensemble import RandomForestRegressor
r=RandomForestRegressor()
r.fit(X_train,y_train)
y_pred=r.score(X_test,y_test)
print((y_pred))
# Out:
# 0.9998664515202534

# %%
from sklearn.linear_model import Lasso

# %%
la=Lasso()
la.fit(X_train,y_train)
print(la.score(X_test,y_test))
# Out:
# 0.9997459687537346
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.399e+05, tolerance: 2.440e+05
#   model = cd_fast.enet_coordinate_descent(

# %%
d2=d1[['Open','Volume','sentiment_score']]
d=d2.corr()

# %%
print(d)
# Out:
#                      Open    Volume  sentiment_score
# Open             1.000000  0.714909         0.630841
# Volume           0.714909  1.000000         0.795253
# sentiment_score  0.630841  0.795253         1.000000

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score,classification_report
d=DecisionTreeRegressor()
d.fit(X_train,y_train)
print(d.score(X_test,y_test))
# Out:
# 0.9997539660612068
