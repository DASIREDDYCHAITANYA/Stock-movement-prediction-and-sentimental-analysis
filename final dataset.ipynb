# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset1='/content/drive/MyDrive/dhoni/dataset1.csv'
dataset2='/content/drive/MyDrive/dhoni/merged_data.csv'

# %%
import pandas as pd
dataset1 = pd.read_csv(dataset1)
dataset2 = pd.read_csv(dataset2)







dataset1['time_published'] = pd.to_datetime(dataset1['time_published'])

dataset1 = dataset1.groupby('time_published').agg({'overall_sentiment_score': 'mean'}).reset_index()

# %%
dataset1
# Out:
#     time_published  overall_sentiment_score
# 0       2023-12-20                 0.125073
# 1       2023-12-21                 0.056316
# 2       2023-12-22                 0.126100
# 3       2023-12-23                 0.052793
# 4       2023-12-24                 0.052296
# ..             ...                      ...
# 249     2024-09-11                 0.222913
# 250     2024-09-12                 0.183484
# 251     2024-09-13                 0.052392
# 252     2024-09-15                 0.111687
# 253     2024-09-16                -0.001106
#
# [254 rows x 2 columns]

# %%
dataset1 = dataset1.rename(columns={'time_published	': 'date', 'overall_sentiment_score': 'sentiment_score'})
dataset2 = dataset2.rename(columns={'date': 'time_published'})

# %%
dataset2
# Out:
#     time_published  sentiment_score
# 0       2021-09-30         0.287539
# 1       2021-10-01         0.257532
# 2       2021-10-02         0.231063
# 3       2021-10-03         0.300087
# 4       2021-10-04         0.124803
# ..             ...              ...
# 360     2022-09-25         0.109272
# 361     2022-09-26         0.135966
# 362     2022-09-27         0.157954
# 363     2022-09-28         0.113234
# 364     2022-09-29         0.077263
#
# [365 rows x 2 columns]

# %%
dataframes = [dataset1, dataset2]


merged_df = pd.concat(dataframes, axis=0, ignore_index=True)


merged_df
# Out:
#           time_published  sentiment_score
# 0    2023-12-20 00:00:00         0.125073
# 1    2023-12-21 00:00:00         0.056316
# 2    2023-12-22 00:00:00         0.126100
# 3    2023-12-23 00:00:00         0.052793
# 4    2023-12-24 00:00:00         0.052296
# ..                   ...              ...
# 614           2022-09-25         0.109272
# 615           2022-09-26         0.135966
# 616           2022-09-27         0.157954
# 617           2022-09-28         0.113234
# 618           2022-09-29         0.077263
#
# [619 rows x 2 columns]

# %%
df3="/content/drive/MyDrive/dhoni/tesla.csv"
df3=pd.read_csv(df3)
df3
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-09-30  260.333344  263.043335  258.333344  258.493347  258.493347
# 1    2021-10-01  259.466675  260.260010  254.529999  258.406677  258.406677
# 2    2021-10-04  265.500000  268.989990  258.706665  260.510010  260.510010
# 3    2021-10-05  261.600006  265.769989  258.066681  260.196655  260.196655
# 4    2021-10-06  258.733337  262.220001  257.739990  260.916656  260.916656
# ..          ...         ...         ...         ...         ...         ...
# 738  2024-09-09  216.199997  219.869995  213.669998  216.270004  216.270004
# 739  2024-09-10  220.070007  226.399994  218.639999  226.169998  226.169998
# 740  2024-09-11  224.550003  228.470001  216.800003  228.130005  228.130005
# 741  2024-09-12  224.660004  231.449997  223.830002  229.809998  229.809998
# 742  2024-09-13  228.000000  232.669998  226.320007  230.289993  230.289993
#
#        Volume
# 0    53868000
# 1    51094200
# ...

# %%
merged_df['time_published'] = pd.to_datetime(merged_df['time_published'])
df3['Date'] = pd.to_datetime(df3['Date'])

final_df = pd.merge(merged_df, df3, left_on='time_published',right_on="Date")

# %%
final_df
# Out:
#     time_published  sentiment_score       Date        Open        High  \
# 0       2023-12-20         0.125073 2023-12-20  256.410004  259.839996
# 1       2023-12-21         0.056316 2023-12-21  251.899994  254.800003
# 2       2023-12-22         0.126100 2023-12-22  256.760010  258.220001
# 3       2023-12-26         0.182736 2023-12-26  254.490005  257.970001
# 4       2023-12-27         0.185232 2023-12-27  258.350006  263.339996
# ..             ...              ...        ...         ...         ...
# 429     2022-09-23         0.149131 2022-09-23  283.089996  284.500000
# 430     2022-09-26         0.135966 2022-09-26  271.829987  284.089996
# 431     2022-09-27         0.157954 2022-09-27  283.839996  288.670013
# 432     2022-09-28         0.113234 2022-09-28  283.079987  289.000000
# 433     2022-09-29         0.077263 2022-09-29  282.760010  283.649994
#
#             Low       Close   Adj Close     Volume
# 0    247.000000  247.139999  247.139999  125097000
# ...

# %%
# Define the path where you want to save the file
file_path = '/content/drive/MyDrive/dhoni/final_dataset.csv'

# Save the DataFrame to a CSV file
final_df.to_csv(file_path, index=False)
